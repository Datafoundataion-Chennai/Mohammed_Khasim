# %%
#Employee Salary Insights

import pandas as pd
data={
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace', 'Hannah'],
    'Department': ['HR', 'IT', 'IT', 'HR', 'Finance', 'Finance', 'IT', 'HR'],
    'Age': [25, 32, 29, 41, 37, 45, 26, 38],
    'Salary': [50000, 70000, 65000, 80000, 75000, 90000, 62000, 85000],
    'Experience': [2, 7, 5, 15, 10, 20, 3, 12]
}
df=pd.DataFrame(data)
avg_salary=df.groupby("Department")['Salary'].mean()
print("Average Salary by Department:\n",avg_salary)

highest_paid = df.loc[df.groupby('Department')['Salary'].idxmax(), ['Employee', 'Department', 'Salary']]
print("\nHighest Paid Employee in Each Department:\n", highest_paid)

experienced_high_salary=df[(df['Experience']>5)&(df['Salary']>65000)]
print("\nEmplyoyees with >5 years experience & salary>$65000:\n",experienced_high_salary)

def seniority(exp):
    if exp<5:
        return "Junior"
    elif 5<=exp<=10:
        return "Mid-Level"
    else:
        return "Senior"

df['Seniority']=df['Experience'].apply(seniority)
print("\nDataFrame with Seniority:\n",df)

sorted_it=df[df['Department'] == 'IT'].sort_values(by='Salary', ascending=False)
print("\nSorted IT Employees by Salary (Descending):\n", sorted_it)
# Out:
# Average Salary by Department:
# Department
# Finance    82500.000000
# HR         71666.666667
# IT         65666.666667
# Name: Salary, dtype: float64
#
# Highest Paid Employee in Each Department:
#    Employee Department  Salary
# 5    Frank    Finance   90000
# 7   Hannah         HR   85000
# 1      Bob         IT   70000
#
# Emplyoyees with >5 years experience & salary>$65000:
#    Employee Department  Age  Salary  Experience
# 1      Bob         IT   32   70000           7
# 3    David         HR   41   80000          15
# 4     Emma    Finance   37   75000          10
# 5    Frank    Finance   45   90000          20
# 7   Hannah         HR   38   85000          12
#
# DataFrame with Seniority:
#   Employee Department  Age  Salary  Experience  Seniority
# 0    Alice         HR   25   50000           2     Junior
# 1      Bob         IT   32   70000           7  Mid-Level
# 2  Charlie         IT   29   65000           5  Mid-Level
# ...

# %%
#Analysing Student Grades

import pandas as pd

data={
    'Student': ['John', 'Sara', 'Mike', 'Anna', 'David', 'Emily', 'Chris', 'Sophia'],
    'Subject': ['Math', 'Science', 'Math', 'Science', 'Math', 'Science', 'Math', 'Science'],
    'Marks': [85, 72, 90, 65, 78, 88, 92, 55],
    'Attendance': [92, 80, 95, 70, 85, 90, 97, 60]
}

df=pd.DataFrame(data)

avg_marks = df.groupby('Subject')['Marks'].mean()
print("Average Marks per Subject:\n", avg_marks)

high_marks_low_attendance = df[(df['Marks'] > 85) & (df['Attendance'] < 90)]
print("\nStudents scoring above 85 with <90% attendance:\n", high_marks_low_attendance)


def assign_grade(marks):
    if marks >= 90:
        return "A"
    elif 80 <= marks < 90:
        return "B"
    elif 70 <= marks < 80:
        return "C"
    else:
        return "D"

df['Grade'] = df['Marks'].apply(assign_grade)
print("\nDataFrame with Grades:\n", df)

grade_counts = df['Grade'].value_counts()
print("\nGrade Distribution:\n", grade_counts)

correlation = df[['Marks', 'Attendance']].corr().iloc[0, 1]
print("\nCorrelation between Marks and Attendance:", correlation)
# Out:
# Average Marks per Subject:
#  Subject
# Math       86.25
# Science    70.00
# Name: Marks, dtype: float64
#
# Students scoring above 85 with <90% attendance:
#  Empty DataFrame
# Columns: [Student, Subject, Marks, Attendance]
# Index: []
#
# DataFrame with Grades:
#    Student  Subject  Marks  Attendance Grade
# 0    John     Math     85          92     B
# 1    Sara  Science     72          80     C
# 2    Mike     Math     90          95     A
# 3    Anna  Science     65          70     D
# 4   David     Math     78          85     C
# 5   Emily  Science     88          90     B
# 6   Chris     Math     92          97     A
# 7  Sophia  Science     55          60     D
#
# Grade Distribution:
#  Grade
# B    2
# C    2
# A    2
# D    2
# Name: count, dtype: int64
#
# Correlation between Marks and Attendance: 0.9901770851376989
